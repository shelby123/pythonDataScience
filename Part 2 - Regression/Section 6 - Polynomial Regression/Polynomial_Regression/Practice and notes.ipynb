# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("Position_Salaries.csv")

# %%
from sklearn.model_selection import train_test_split
X = df.Level.values.reshape(-1, 1)
y = df.Salary.values

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=0)

# %%
# Linear regression...
from sklearn.linear_model import LinearRegression
linear_regressor = LinearRegression().fit(X, y)

# %%
from sklearn.preprocessing import PolynomialFeatures

polyFeature = PolynomialFeatures(degree=4)
X_Poly = polyFeature.fit_transform(X)
poly_regressor = LinearRegression().fit(X_Poly, y)

# %%
X_grid = np.arange(start = min(X), stop = max(X), step = .1)
X_grid = X_grid.reshape((len(X_grid), 1))

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [10, 10]

plt.scatter(X, y, color='cyan')
plt.plot(X, linear_regressor.predict(X), color='purple')
plt.plot(X_grid, poly_regressor.predict(polyFeature.fit_transform(X_grid)), color='orange')

# %%
display(poly_regressor.predict(polyFeature.fit_transform([[6.5]])))
display(linear_regressor.predict([[6.5]]))
# Out:
# array([158862.45265153])
# array([330378.78787879])
